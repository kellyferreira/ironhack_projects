# %% [markdown]
# ### Escape Room Python Project

# %% [markdown]
# Definindo os ambientes e itens:

# %%
#furniture

couch = {
    "name": "couch",
    "type": "furniture",
}

piano = {
    "name": "piano",
    "type": "furniture",
}

queen_bed = {
    "name": "queen_bed",
    "type": "furniture",
}

double_bed = {
    "name": "double_bed",
    "type": "furniture",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

dining_table = {
    "name": "dining_table",
    "type": "furniture",
}

door_a = {
    "name": "door_a",
    "type": "door",
}

door_b = {
    "name": "door_b",
    "type": "door",
}

door_c = {
    "name": "door_c",
    "type": "door",
}

door_d = {
    "name": "door_d",
    "type": "door",
}

#keys

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

#rooms
game_room = {
    "name": "game_room",
    "type": "room",
}

bed_room1 = {
    "name": "bed_room1",
    "type": "room",
}

bed_room2 = {
    "name": "bed_room2",
    "type": "room",
}

living_room = {
    "name": "living_room",
    "type": "room",
}

outside = {
  "name": "outside"
}

all_rooms = [game_room, bed_room1, bed_room2, living_room, outside]

all_doors = [door_a, door_b, door_c, door_d]

# defining which items/rooms are related

object_relations = {
    "game_room": [couch, piano, door_a],
    "bed_room1": [queen_bed, door_a, door_b, door_c],
    "bed_room2": [double_bed, dresser, door_b],
    "living_room": [dining_table, door_c, door_d],
    "outside": [door_d],

    "piano": [key_a],
    "queen_bed": [key_b],
    "double_bed":[key_c],
    "dresser": [key_d],
    
    "door_a": [game_room, bed_room1],
    "door_b": [bed_room1, bed_room2],
    "door_c": [bed_room1, living_room],
    "door_d": [living_room, outside],
}



INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %% [markdown]
# Definindo as funções de início do jogo e verificação.

# %%
def main():
    print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!!\n")
    
    while gs['current_room'] != gs['target_room']:
        
        roomname = gs['current_room']['name']
        i = 1
        
        for objeto in object_relations[roomname]:
            print(str(i), "- check", objeto['name'], '\n')
            i+=1

        op = int(input("Choose an option: "))

        objeto = object_relations[roomname][op-1]

        verifica(objeto)
        
        
    print("Congrats!! You escaped the room! ;)\n")

def verifica(objeto):
 
    if(objeto['type'] == 'door'):
        print("Checking the door...")
        
        for k in gs['keys_collected']:
                
            target = k['target']
                
            if(target == objeto):
                print("You open the door!\n")

                if(object_relations[objeto['name']][0] == gs['current_room']):
                    gs['current_room'] = object_relations[objeto['name']][1]
                
                else:
                    gs['current_room'] = object_relations[objeto['name']][0]

                
                print("Now You're in the ", gs['current_room']['name'], '\n')
                
                return
                
        print("You didn't find the key :(\n")
        return

    if(objeto['type'] == 'furniture'):
        try:
            key = object_relations[objeto['name']][0]
        except:
            print("There's nothing here!\n")
            return

    if(key in gs['keys_collected']):
        print("You already got this key!\n")
    else:
        print("You got the key!", key['name'], '\n')
        gs['keys_collected'].append(key)

    return

# %%
gs = INIT_GAME_STATE.copy()
main()
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!!
#
# 1 - check couch
#
# 2 - check piano
#
# 3 - check door_a
